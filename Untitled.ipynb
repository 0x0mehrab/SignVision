# %%
import cv2
import os
import time
import uuid

# %%
IMAGES_PATH = 'Tensorflow/workspace/images/collectedimages'

# %%
labels = ['good_luck', 'thank_you', 'i_have_a_question', 'live_long_and_prosper', 'call_me']
number_imgs = 20

# %%
CAMERA_INDEX = 0

# %%
# === Open Webcam and Set Resolution to 1280x720 ===
cap = cv2.VideoCapture(CAMERA_INDEX, cv2.CAP_DSHOW)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

if not cap.isOpened():
    print(f"❌ Camera index {CAMERA_INDEX} could not be opened.")
    exit()

# === Image Collection Loop ===
for label in labels:
    label_path = os.path.join(IMAGES_PATH, label)
    os.makedirs(label_path, exist_ok=True)

    # Countdown before capture
    countdown_start = time.time()
    while True:
        ret, frame = cap.read()
        if not ret:
            print("❌ Failed to grab frame")
            continue

        seconds_elapsed = int(time.time() - countdown_start)
        countdown = 3 - seconds_elapsed
        if countdown <= 0:
            break

        text = f"Get ready for: {label.replace('_', ' ')} - Starting in {countdown}s"
        display_frame = frame.copy()
        cv2.putText(display_frame, text, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)
        cv2.imshow("Sign Collector", display_frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            cap.release()
            cv2.destroyAllWindows()
            exit()

    print(f"\n📸 Collecting images for: {label}")
    imgnum = 0
    last_capture = time.time()

    while imgnum < number_imgs:
        ret, frame = cap.read()
        if not ret:
            print("❌ Failed to grab frame")
            continue

        if time.time() - last_capture >= 1:
            imgname = os.path.join(label_path, f"{label}.{uuid.uuid1()}.jpg")
            cv2.imwrite(imgname, frame)
            print(f"✅ Saved: {imgname}")
            imgnum += 1
            last_capture = time.time()

        display_frame = frame.copy()
        overlay_text = f"Sign: {label.replace('_', ' ')} | Image: {imgnum+1}/{number_imgs}"
        cv2.putText(display_frame, overlay_text, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
        cv2.imshow("Sign Collector", display_frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            print("❌ Quitting early.")
            cap.release()
            cv2.destroyAllWindows()
            exit()

    # Wait 5 seconds before next label
    prepare_start = time.time()
    while True:
        ret, frame = cap.read()
        if not ret:
            print("❌ Failed to grab frame")
            continue

        seconds_passed = int(time.time() - prepare_start)
        countdown = 5 - seconds_passed
        if countdown <= 0:
            break

        text = f"Prepare for next sign: {countdown}s"
        display_frame = frame.copy()
        cv2.putText(display_frame, text, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 255), 2)
        cv2.imshow("Sign Collector", display_frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            cap.release()
            cv2.destroyAllWindows()
            exit()

print("✅ Image collection complete.")
cap.release()
cv2.destroyAllWindows()
# Out:
# 📸 Collecting images for: good_luck
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.b35ef130-4861-11f0-98c5-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.b404ce74-4861-11f0-8e35-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.b4ad63f6-4861-11f0-a44f-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.b5555ed0-4861-11f0-b7c2-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.b5fbd5b4-4861-11f0-ab8e-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.b6a42f9a-4861-11f0-97fb-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.b74a5826-4861-11f0-ac49-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.b7f2cf74-4861-11f0-b390-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.b89b4680-4861-11f0-aae9-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.b9412078-4861-11f0-8973-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.b9e9993e-4861-11f0-a75d-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.ba923752-4861-11f0-9209-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.bb383390-4861-11f0-906d-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.bbe08354-4861-11f0-903e-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.bc8920fa-4861-11f0-a04b-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.bd2f2f2e-4861-11f0-9095-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.bdd77540-4861-11f0-b8ad-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.be7f1e12-4861-11f0-9766-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.bf263d46-4861-11f0-950a-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\good_luck\good_luck.bfce3a3e-4861-11f0-80c3-50a1325bc974.jpg
#
# 📸 Collecting images for: thank_you
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.c548126e-4861-11f0-b146-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.c5efb608-4861-11f0-a58a-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.c698fb70-4861-11f0-94b1-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.c73ef986-4861-11f0-a7ac-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.c7e74c02-4861-11f0-9e77-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.c88fc37a-4861-11f0-a827-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.c935d0ba-4861-11f0-84cf-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.c9de43de-4861-11f0-886a-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.ca86ad9e-4861-11f0-9e75-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.cb2cdcfe-4861-11f0-a83d-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.cbd4dcca-4861-11f0-a583-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.cc7dc722-4861-11f0-ab1e-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.cd239ee8-4861-11f0-917d-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.cdcbce7a-4861-11f0-93d9-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.ce722b26-4861-11f0-9609-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.cf1a943a-4861-11f0-9bc2-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.cfc32fae-4861-11f0-8931-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.d0690c18-4861-11f0-9fa9-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.d111a7dc-4861-11f0-90cf-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\thank_you\thank_you.d1b9f59a-4861-11f0-9b18-50a1325bc974.jpg
#
# 📸 Collecting images for: i_have_a_question
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.d74222da-4861-11f0-9073-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.d7ea6e36-4861-11f0-866a-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.d892b0ba-4861-11f0-a6f2-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.d9391052-4861-11f0-a86b-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.d9e15dee-4861-11f0-8de5-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.da89a8da-4861-11f0-b744-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.db2fce26-4861-11f0-a745-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.dbd84acc-4861-11f0-bc02-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.dc80912e-4861-11f0-b62a-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.dd26eb62-4861-11f0-96d1-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.ddcf394c-4861-11f0-985f-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.de753ff8-4861-11f0-bc4d-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.df1dac40-4861-11f0-9871-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.dfc62818-4861-11f0-ba20-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.e06c4154-4861-11f0-9896-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.e114a502-4861-11f0-bdbf-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.e1bd249c-4861-11f0-afc2-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.e263419e-4861-11f0-a95e-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.e30b6af8-4861-11f0-b1a3-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\i_have_a_question\i_have_a_question.e3b3f8c0-4861-11f0-8b04-50a1325bc974.jpg
#
# 📸 Collecting images for: live_long_and_prosper
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.e93be29c-4861-11f0-b438-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.e9e4a7ae-4861-11f0-a432-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.ea8d064a-4861-11f0-8074-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.eb331e12-4861-11f0-97ff-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.ebdb6d52-4861-11f0-9c67-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.ec83e2c8-4861-11f0-b147-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.ed29e298-4861-11f0-944e-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.edd25a46-4861-11f0-8fbe-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.ee7ac322-4861-11f0-bce7-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.ef20c3e4-4861-11f0-89d7-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.efc9451c-4861-11f0-b165-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.f06e5e90-4861-11f0-8f3a-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.f117c330-4861-11f0-a07b-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.f1bf5d66-4861-11f0-874a-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.f26637f6-4861-11f0-8b2e-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.f30ed862-4861-11f0-8bc8-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.f3b72446-4861-11f0-8285-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.f45d27d2-4861-11f0-a20c-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.f505a27a-4861-11f0-ba74-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\live_long_and_prosper\live_long_and_prosper.f5ae10f8-4861-11f0-ab7d-50a1325bc974.jpg
#
# 📸 Collecting images for: call_me
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.fb364348-4861-11f0-850b-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.fbde9108-4861-11f0-ad41-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.fc8706f0-4861-11f0-851f-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.fd2ce34c-4861-11f0-b630-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.fdd57f92-4861-11f0-a64a-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.fe7df7d2-4861-11f0-af52-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.ff23f658-4861-11f0-a5dc-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.ffcc6b88-4861-11f0-b2a2-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.0072761e-4862-11f0-bc2d-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.011ada1a-4862-11f0-8140-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.01c32b74-4862-11f0-bc91-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.026986c0-4862-11f0-871e-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.0311d4e8-4862-11f0-94bd-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.03ba49e6-4862-11f0-8ae8-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.04604090-4862-11f0-ab57-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.050911a8-4862-11f0-aeae-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.05b128d4-4862-11f0-a32d-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.0656ece4-4862-11f0-bd1f-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.06ff9adc-4862-11f0-90a6-50a1325bc974.jpg
# ✅ Saved: Tensorflow/workspace/images/collectedimages\call_me\call_me.07a82858-4862-11f0-af97-50a1325bc974.jpg
# ✅ Image collection complete.
